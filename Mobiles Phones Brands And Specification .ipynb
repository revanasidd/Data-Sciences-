# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import re
import requests
from bs4 import BeautifulSoup 

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
url='https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_1_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_1_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobiles%7CMobiles&requestId=4982b5d5-79bc-4d31-b0e0-d5ec88e83424&as-searchtext=m'
page=requests.get(url)
page
# Out:
# <Response [200]>

# %%
pagecontent=page.text
pagecontent
# Out:
# '<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.8683fa.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pro
# ...

# %%
soup=BeautifulSoup(pagecontent)

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <link href="https://rukminim1.flixcart.com" rel="dns-prefetch"/>
# <link href="https://img1a.flixcart.com" rel="dns-prefetch"/>
# <link href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.8683fa.css" rel="stylesheet"/>
# <link as="image" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" rel="preload"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="102988293558" property="fb:page_id"/>
# <meta content="658873552,624500995,100000233612389" property="fb:admins"/>
# <meta content="noodp" name="robots"/>
# <link href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" rel="shortcut icon"/>
# <link href="/osdd.xml?v=2" rel="search" type="application/opensearchdescription+xml"/>
# <meta content="website" property="og:type"/>
# ...

# %%
soup.find_all('div',attrs={'class':'_1-2Iqu row'})
# Out:
# [<div class="_1-2Iqu row"><div class="col col-7-12"><div class="_3wU53n">Realme C11 (Rich Grey, 32 GB)</div><div class="niH0FQ"><span class="_2_KrJI" id="productRating_LSTMOBFTAYBBVKFEGTZWP31JF_MOBFTAYBBVKFEGTZ_"><div class="hGSR34">4.4<img class="_2lQ_WZ" src="..."/></div></span><span class="_38sUEc"><span><span>1,72,682 Ratings </span><span class="_1VpSqZ">&amp;</span><span> 11,538 Reviews</span></span></span></div><div class="_3ULzGw"><ul class="vFw0gD"><li class="tVe95H">2 GB RAM | 32 GB ROM | Expandable Upto 256 GB</li><li class="tVe95H">16.51 cm (6.5 inch) HD+ Display</li><li class="tVe95H">13MP + 2MP | 5MP Front Camera</li><li class="tVe95H">5000 mAh Battery</li><li class="tVe95H">Mediatek Helio G35 Processor</li><li class="tVe95H">Brand Warranty of 1 Year Available for Mobile and 6 Months for Accessories</li></ul></div></div><div class="col col-5-12 _2o7WAb"><div class="_6BWGkk"><div class="_1uv9Cb"><div class="_1vC4OE _2rQ-NK">₹6,999</div><div class="_3auQ3N _2GcJzG">₹<!-- -
# ...

# %%
for pn in soup.find_all('div',attrs={'class':'_1-2Iqu row'}):
    productname=pn.find('div',attrs={'class':'_3wU53n'})
    if productname is None:
        print(np.nan)
    else:
        print(productname.text)
# Out:
# Realme C11 (Rich Grey, 32 GB)
# Realme C11 (Rich Green, 32 GB)
# Realme C12 (Power Silver, 32 GB)
# Realme C12 (Power Blue, 32 GB)
# Realme C15 (Power Blue, 64 GB)
# Realme C15 (Power Blue, 32 GB)
# Realme C15 (Power Silver, 32 GB)
# Realme Narzo 20 (Victory Blue, 128 GB)
# Redmi 9i (Nature Green, 64 GB)
# Realme C15 (Power Silver, 64 GB)
# Apple iPhone SE (Black, 64 GB)
# Redmi 9i (Midnight Black, 64 GB)
# Redmi 9i (Sea Blue, 64 GB)
# Realme Narzo 20 (Glory Silver, 64 GB)
# Realme Narzo 20A (Victory Blue, 32 GB)
# Realme Narzo 20A (Glory Silver, 32 GB)
# Realme Narzo 20A (Glory Silver, 64 GB)
# Realme Narzo 20A (Victory Blue, 64 GB)
# POCO X3 (Cobalt Blue, 128 GB)
# Realme 7i (Fusion Green, 128 GB)
# Realme 7i (Fusion Green, 64 GB)
# Realme 7i (Fusion Blue, 64 GB)
# Realme 7i (Fusion Blue, 128 GB)
# Apple iPhone SE (White, 64 GB)

# %%
import time
ProductName=[]
Price=[]
Discount=[]
Specification=[]
Ratings=[]
Pages=[]
for i in range(1,24):
    start_time=time.time()
    url='https://www.flipkart.com/search?q=mobiles&sid=tyy%2C4io&as=on&as-show=on&otracker=AS_QueryStore_HistoryAutoSuggest_1_1_na_na_na&otracker1=AS_QueryStore_HistoryAutoSuggest_1_1_na_na_na&as-pos=1&as-type=HISTORY&suggestionId=mobiles%7CMobiles&requestId=4982b5d5-79bc-4d31-b0e0-d5ec88e83424&as-searchtext=m'
    page=requests.get(url)
    pagecontent=page.text
    soup=BeautifulSoup(pagecontent)
    for pn in soup.find_all('div',attrs={'class':'_1-2Iqu row'}):
        pname=pn.find('div',attrs={'class':'_3wU53n'})
        cost=pn.find('div',attrs={'class':'_1vC4OE _2rQ-NK'})
        dis=pn.find('div',attrs={'class':'VGWI6T'})
        rate=pn.find('span',attrs={'class':'_38sUEc'})
        spec=pn.find('ul',attrs={'class':'vFw0gD'})
        if pname is None:
            Productname.append(np.nan)
        else:
            ProductName.append(pname.text)

        if cost is None:
            Price.append(np.nan)
        else:
            Price.append(cost.text)
        
        if dis is None:
            Discount.append(np.nan)
        else:
            Discount.append(dis.text)
            
        if rate is None:
            Ratings.append(np.nan)
        else:
            Ratings.append(rate.text)
            
        if spec is None:
            Specification.append(np.nan)
        else:
            Specification.append(spec.text)
            
        Pages.append(page)
    print('Page {} complted in {} sec'.format(i, time.time()-start_time))
# Out:
# Page 1 complted in 1.3661744594573975 sec
# Page 2 complted in 1.8517677783966064 sec
# Page 3 complted in 1.90557861328125 sec
# Page 4 complted in 1.214108943939209 sec
# Page 5 complted in 1.5524840354919434 sec
# Page 6 complted in 1.862894058227539 sec
# Page 7 complted in 1.3131818771362305 sec
# Page 8 complted in 1.4051895141601562 sec
# Page 9 complted in 1.621157169342041 sec
# Page 10 complted in 1.2940723896026611 sec
# Page 11 complted in 1.2317900657653809 sec
# Page 12 complted in 1.1511380672454834 sec
# Page 13 complted in 1.3555893898010254 sec
# Page 14 complted in 1.2434394359588623 sec
# Page 15 complted in 1.1633143424987793 sec
# Page 16 complted in 1.331101417541504 sec
# Page 17 complted in 2.0787250995635986 sec
# Page 18 complted in 1.1503102779388428 sec
# Page 19 complted in 1.3362648487091064 sec
# Page 20 complted in 1.2241852283477783 sec
# Page 21 complted in 1.5149626731872559 sec
# Page 22 complted in 1.1694824695587158 sec
# ...

# %%
len(ProductName)
len(Price)
len(Discount)
len(Specification)
len(Ratings)
# Out:
# 552
# 552
# 552
# 552
# 552

# %%
mobiles=pd.DataFrame({'ProductName':ProductName,'Price':Price,'Discount':Discount,'Specification':Specification,'Ratings':Ratings})

# %%
mobiles
# Out:
#                           ProductName    Price Discount  \
# 0       Realme C11 (Rich Grey, 32 GB)   ₹6,999  22% off
# 1      Realme C11 (Rich Green, 32 GB)   ₹6,999  22% off
# 2      Realme C12 (Power Blue, 32 GB)   ₹7,999  27% off
# 3    Realme C12 (Power Silver, 32 GB)   ₹7,999  27% off
# 4      Realme C15 (Power Blue, 64 GB)   ₹9,499  26% off
# ..                                ...      ...      ...
# 547  Realme 7i (Fusion Green, 128 GB)  ₹12,999  13% off
# 548   Realme 7i (Fusion Green, 64 GB)  ₹11,999  14% off
# 549    Realme 7i (Fusion Blue, 64 GB)  ₹11,999  14% off
# 550   Realme 7i (Fusion Blue, 128 GB)  ₹12,999  13% off
# 551    Apple iPhone SE (White, 64 GB)  ₹29,999  29% off
#
#                                          Specification  \
# 0    2 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...
# 1    2 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...
# 2    3 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...
# 3    3 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...
# ...

# %%
# Save df to csv
# mobiles.to_csv(r'C:\Users\revan\Desktop\Datascience\Project\Mobilesdata.csv')
Mobilesdata=pd.read_csv('Mobilesdata.csv')

# %%
Mobilesdata
# Out:
#      Unnamed: 0                       ProductName    Price Discount  \
# 0             0     Realme C11 (Rich Grey, 32 GB)   ₹6,999  22% off
# 1             1    Realme C11 (Rich Green, 32 GB)   ₹6,999  22% off
# 2             2    Realme C12 (Power Blue, 32 GB)   ₹7,999  27% off
# 3             3  Realme C12 (Power Silver, 32 GB)   ₹7,999  27% off
# 4             4    Realme C15 (Power Blue, 64 GB)   ₹9,499  26% off
# ..          ...                               ...      ...      ...
# 547         547  Realme 7i (Fusion Green, 128 GB)  ₹12,999  13% off
# 548         548   Realme 7i (Fusion Green, 64 GB)  ₹11,999  14% off
# 549         549    Realme 7i (Fusion Blue, 64 GB)  ₹11,999  14% off
# 550         550   Realme 7i (Fusion Blue, 128 GB)  ₹12,999  13% off
# 551         551    Apple iPhone SE (White, 64 GB)  ₹29,999  29% off
#
#                                          Specification  \
# 0    2 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...
# ...

# %%
Mobilesdata['Specification'][0]
# Out:
# '2 GB RAM | 32 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display13MP + 2MP | 5MP Front Camera5000 mAh BatteryMediatek Helio G35 ProcessorBrand Warranty of 1 Year Available for Mobile and 6 Months for Accessories'

# %%
Mobilesdata
# Out:
#      Unnamed: 0                       ProductName    Price Discount  \
# 0             0     Realme C11 (Rich Grey, 32 GB)   ₹6,999  22% off
# 1             1    Realme C11 (Rich Green, 32 GB)   ₹6,999  22% off
# 2             2    Realme C12 (Power Blue, 32 GB)   ₹7,999  27% off
# 3             3  Realme C12 (Power Silver, 32 GB)   ₹7,999  27% off
# 4             4    Realme C15 (Power Blue, 64 GB)   ₹9,499  26% off
# ..          ...                               ...      ...      ...
# 547         547  Realme 7i (Fusion Green, 128 GB)  ₹12,999  13% off
# 548         548   Realme 7i (Fusion Green, 64 GB)  ₹11,999  14% off
# 549         549    Realme 7i (Fusion Blue, 64 GB)  ₹11,999  14% off
# 550         550   Realme 7i (Fusion Blue, 128 GB)  ₹12,999  13% off
# 551         551    Apple iPhone SE (White, 64 GB)  ₹29,999  29% off
#
#                                          Specification  \
# 0    2 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...
# ...

# %%
regex = r'\d\d\d\d\s\w+'

re.compile(regex).findall(Mobilesdata['Specification'][0])

Mobilesdata['Battery'] = Mobilesdata['Specification'].apply(lambda x:re.compile(regex).findall(x))
# Out:
# ['5000 mAh']

# %%
Mobilesdata
# Out:
#      Unnamed: 0                       ProductName    Price Discount  \
# 0             0     Realme C11 (Rich Grey, 32 GB)   ₹6,999  22% off
# 1             1    Realme C11 (Rich Green, 32 GB)   ₹6,999  22% off
# 2             2    Realme C12 (Power Blue, 32 GB)   ₹7,999  27% off
# 3             3  Realme C12 (Power Silver, 32 GB)   ₹7,999  27% off
# 4             4    Realme C15 (Power Blue, 64 GB)   ₹9,499  26% off
# ..          ...                               ...      ...      ...
# 547         547  Realme 7i (Fusion Green, 128 GB)  ₹12,999  13% off
# 548         548   Realme 7i (Fusion Green, 64 GB)  ₹11,999  14% off
# 549         549    Realme 7i (Fusion Blue, 64 GB)  ₹11,999  14% off
# 550         550   Realme 7i (Fusion Blue, 128 GB)  ₹12,999  13% off
# 551         551    Apple iPhone SE (White, 64 GB)  ₹29,999  29% off
#
#                                          Specification  \
# 0    2 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...
# ...

# %%
Mobilesdata['Specification'][0]

Mobilesdata['Specification'][5]

Mobilesdata['Specification'][10]
# Out:
# '2 GB RAM | 32 GB ROM | Expandable Upto 256 GB16.51 cm (6.5 inch) HD+ Display13MP + 2MP | 5MP Front Camera5000 mAh BatteryMediatek Helio G35 ProcessorBrand Warranty of 1 Year Available for Mobile and 6 Months for Accessories'
# '3 GB RAM | 32 GB ROM | Expandable Upto 256 GB16.56 cm (6.52 inch) HD+ Display13MP + 8MP + 2MP + 2MP | 8MP Front Camera6000 mAh Lithium-ion BatteryMediatek Helio G35 ProcessorBrand Warranty of 1 Year Available for Mobile and 6 Months for Accessories'
# '64 GB ROM11.94 cm (4.7 inch) Retina HD Display12MP Rear Camera | 7MP Front CameraA13 Bionic Chip with 3rd Gen Neural Engine ProcessorWater and Dust Resistant (1 meter for Upto 30 minutes, IP67)Fast Charge CapableWireless charging (Works with Qi Chargers | Qi Chargers are Sold SeparatelyBrand Warranty for 1 Year'

# %%
regex=r'[0-9][\sA-Za-z0-9]+RAM'
re.compile(regex).findall(Mobilesdata['Specification'][0])
Mobilesdata['RAM']=Mobilesdata['Specification'].apply(lambda x:re.compile(regex).findall(x))
# Out:
# ['2 GB RAM']

# %%
regex=r'Mediatek[\sA-Za-z0-9]+Processor'
re.compile(regex).findall(Mobilesdata['Specification'][0])
Mobilesdata['Processor']=Mobilesdata['Specification'].apply(lambda x:re.compile(regex).findall(x))
# Out:
# ['Mediatek Helio G35 Processor']

# %%
Mobilesdata['ROM']=Mobilesdata['Specification'].apply(lambda x:re.compile(r'[0-9][\sA-Za-z0-9]+ROM').findall(x))

# %%
Mobilesdata['Display']=Mobilesdata['Specification'].apply(lambda display:re.compile(r'.......................[\sA-Za-z0-9]+Display').findall(display))

# %%
regex = r'^\w+'

Mobilesdata['Brand'] = Mobilesdata['ProductName'].apply(lambda x:re.compile(regex).findall(x))

# %%
''.join(Mobilesdata.Brand[0])
# Out:
# 'Realme'

# %%
Mobilesdata.Processor = Mobilesdata.Processor.apply(lambda x:''.join(x))
Mobilesdata.Battery = Mobilesdata.Battery.apply(lambda x:''.join(x))
Mobilesdata.RAM = Mobilesdata.RAM.apply(lambda x:''.join(x))
Mobilesdata.Display = Mobilesdata.Display.apply(lambda x:''.join(x))
Mobilesdata.ROM = Mobilesdata.ROM.apply(lambda x:''.join(x))
Mobilesdata.Brand = Mobilesdata.Brand.apply(lambda x:''.join(x))

# %%
Mobilesdata
# Out:
#      Unnamed: 0                       ProductName Discount  \
# 0             0     Realme C11 (Rich Grey, 32 GB)  22% off
# 1             1    Realme C11 (Rich Green, 32 GB)  22% off
# 2             2    Realme C12 (Power Blue, 32 GB)  27% off
# 3             3  Realme C12 (Power Silver, 32 GB)  27% off
# 4             4    Realme C15 (Power Blue, 64 GB)  26% off
# ..          ...                               ...      ...
# 547         547  Realme 7i (Fusion Green, 128 GB)  13% off
# 548         548   Realme 7i (Fusion Green, 64 GB)  14% off
# 549         549    Realme 7i (Fusion Blue, 64 GB)  14% off
# 550         550   Realme 7i (Fusion Blue, 128 GB)  13% off
# 551         551    Apple iPhone SE (White, 64 GB)  29% off
#
#                                          Specification  \
# 0    2 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...
# 1    2 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...
# 2    3 GB RAM | 32 GB ROM | Expandable Upto 256 GB1...
# ...

# %%
Mobilesdata.columns
# Out:
# Index(['Unnamed: 0', 'ProductName', 'Price', 'Discount', 'Specification',
#        'Ratings', 'Battery', 'RAM', 'Processor', 'ROM', 'Display', 'Brand'],
#       dtype='object')

# %%
Names=Mobilesdata.ProductName.head(10)
Names
price=Mobilesdata.Prices.head(10)
price
# Out:
# 0             Realme C11 (Rich Grey, 32 GB)
# 1            Realme C11 (Rich Green, 32 GB)
# 2            Realme C12 (Power Blue, 32 GB)
# 3          Realme C12 (Power Silver, 32 GB)
# 4            Realme C15 (Power Blue, 64 GB)
# 5            Realme C15 (Power Blue, 32 GB)
# 6          Realme C15 (Power Silver, 32 GB)
# 7    Realme Narzo 20 (Victory Blue, 128 GB)
# 8          Realme C15 (Power Silver, 64 GB)
# 9            Redmi 9i (Nature Green, 64 GB)
# Name: ProductName, dtype: object
# 0     6,999
# 1     6,999
# 2     7,999
# 3     7,999
# 4     9,499
# 5     8,499
# 6     8,499
# 7    11,499
# 8     9,499
# 9     8,299
# Name: Prices, dtype: object

# %% [markdown]
# ## Data Visualization

# %%
sns.set()
plt.plot(price,Names,'r-')
plt.scatter(price,Names)

# %%
re.compile(r"\d+,\d+").findall(Mobilesdata['Price'][0])
# Out:
# ['6,999']

# %%
regex = r"\d+,\d+"
re.compile(regex).findall(Mobilesdata['Price'][0])
Mobilesdata['Prices']=Mobilesdata['Price'].apply(lambda x:re.compile(regex).findall(x))
Mobilesdata.Price
# Out:
# ['6,999']

# %%
Mobilesdata.Prices=Mobilesdata.Prices.apply(lambda x:''.join(x))

# %%
Mobilesdata.Prices
# Out:
# 0       6,999
# 1       6,999
# 2       7,999
# 3       7,999
# 4       9,499
#         ...
# 547    12,999
# 548    11,999
# 549    11,999
# 550    12,999
# 551    29,999
# Name: Prices, Length: 552, dtype: object

# %%
dtype.Pric
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-98-6240e8cc8deb> in <module>
# ----> 1 Mobilesdata['Prices'].astype(int).dtype
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# --> 582         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     583
#     584     def convert(self, **kwargs):
#
# ...
